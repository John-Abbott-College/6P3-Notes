# %% [markdown]
# # Intro to Python for Developers
#
# This is a brief introduction to Python for developers. It includes two parts:
#
# 1. Python vs C#
# 2. Python OOP
#
# > See notes [Python Dev Environment](https://john-abbott-college.github.io/6P3-Notes/#/wk1/vscode-python-setup) for setup instructions.

# %% [markdown]
# ## Data Types
#
# >  🐍📖 Official Docs on [Python Built-in Types](https://docs.python.org/3/library/stdtypes.html)
#
# Python basic data types:

# %% [markdown]
# ![python-data-types.png](data:image/png;base64,...)
#
# _Source: [Scaler.com, What is Type Casting in Python?](https://www.scaler.com/topics/type-casting-in-python/)_

# %% [markdown]
# >**Python is weakly typed**: data types **don't need to be specified**.
# >
# >However, it's **strongly recommended** to include types for **IDE Type Hints**.

# %%
# Specifying data types
price: float = 1.99
name: str = "Mauricio"
is_cold: bool = True

# %% [markdown]
# ### Checking & Comparing
#
# Use `type( )` to check variable data-type.

# %%
print( type(price) )
print( type(name) )

# %% [markdown]
# Use `isinstance(a, B)` to compare if **object** `a` is instance of class `B` .

# %%
print( isinstance(price, float) )
print( isinstance(name, float) )

# %% [markdown]
# ## Numbers

# %% [markdown]
# ### Implicit Number Type-casting
#
# When mixing different numeric types:
# **The "simpler" number will match the more "complex" number.**
#
# From simple to complex:
# - `integer` < `float` < `complex`
#
# In a **Boolean context**:
# - zero values are false
# - non-zero values are true

# %% [markdown]
# ## Strings
#
# String are **immutable sequences of Unicode**.

# %% [markdown]
# ### String Docs
#
# - Since a string is a sequence of Unicode, it implements all [Python Common Sequence Operations](https://docs.python.org/3/library/stdtypes.html#typesseq-common).
#
# - List of supported [String methods](https://docs.python.org/3/library/stdtypes.html#string-methods).
#
# - Advanced string methods: [Custom String Formatting](https://docs.python.org/3/library/string.html#custom-string-formatting)

# %% [markdown]
# ### String Examples
#
# Mixing operators between numbers and strings is not supported:

# %%
# TypeError in Python but ok in C#
print(1 + "hello")

# %% [markdown]
# Add `r `before the first quote for **raw strings** _(ignore special characters)_

# %%
print(r'C:\win32\new')

# %% [markdown]
# There is no "character-type". A character is simply a **string of size one**

# %%
word = 'Python'
type( word[0] )

# %% [markdown]
# Strings can be **sliced**, however, since since they are immutable, this **will produce a new string**.

# %%
word[2:5]  # characters from position 2 (included) to 5 (excluded)

# %% [markdown]
# ### String formatting
#
# There are common ways of formatting strings:
# - `str.format()`
# - f-strings
#
# > **Use F-strings** for Python 3.6 or above.
# > - Simpler syntax
# > - Faster performance than  `str.format()`.
# > - Same as `$" "` syntax in C#.
#
# F-strings are also called _Formatted string literals_. See [docs for details](https://docs.python.org/3/reference/lexical_analysis.html#f-strings).

# %% [markdown]
# To write an f-string, simple add a `f` or `F` in front of the string:

# %%
name = "Eric"
age = 74
print( f"Hello, {name}. You are {age}." )

# %% [markdown]
# More on F-strings:
#
# - [Python 3's f-Strings: An Improved String Formatting Syntax (Guide)](https://realpython.com/python-f-strings/#python-f-strings-the-pesky-details) to learn more about f-strings and other string formatting approaches.

# %% [markdown]
# ## `list`, `tuple`, `range`
#
# There are three basic **sequence types**:
#
# - lists _(mutable)_
# - tuples _(immutable)_
# - range _(immutable)_
#
# [Common Sequence Operations](https://docs.python.org/3/library/stdtypes.html#typesseq-common) (official docs)
# [Mutable Sequence Operations](https://docs.python.org/3/library/stdtypes.html#typesseq-mutable) (official docs)

# %% [markdown]
# ### Lists: "JS arrays"
#
# Lists in Python are **mutable sequences** (like JavaScript arrays).
# Docs for [List methods](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists).

# %%
a_list = ['example', True, 3.1416, 123]  # mixing types!

print( a_list[-1] )  # last item

a_list.append(False)

print( 'example' in a_list )  # check if present in list

print( a_list.index(123) )  # find index of item '123'

# %% [markdown]
# ### Tuples: immutable lists
#
# Tuples are like Lists, however, **they are immutable**.
#
# See docs for [Tuple data type](https://docs.python.org/3/library/stdtypes.html#tuples) and additional notes on [Tuples and Sequences](https://docs.python.org/3/tutorial/datastructures.html#tuples-and-sequences).

# %%
a_tuple = ('example', True, 3.1416, 123)

print( 'example' in a_tuple )

print( a_tuple.index(123) )

a_tuple.append(False)  # AttributeError

# %% [markdown]
# ### range() == for loop
#
# The `range()` function returns an iterable a sequence.
#
# Python does not have a "traditional" for loop. Instead, it uses the `for in` combined with the `range()` function.

# %%
list(range(5))

# %% [markdown]
# Note:
# - To "see" the range, create a `list` from the iterable range.
# - Otherwise, the range is not "expanded" it is iterated (for performance)
#
# See Docs for [The range() Function](https://docs.python.org/3/tutorial/controlflow.html#the-range-function).

# %% [markdown]
# > **⚠️ Indentation is very important in Python! ⚠️**
#
# Use your IDE to format your code!

# %%
for i in range(5):
    print(i)        # watch your indentation!

# %% [markdown]
# To iterate over the indices of a sequence:

# %%
a = ['Mary', 'had', 'a', 'little', 'lamb']
for i in range(len(a)):
    print(i, a[i])

# %% [markdown]
# ## Dictionaries: mapping keys to objects
#
# Dictionaries are **mutable** made of key-value pairs.
#
# - Docs for a [list of dictionary operations](https://docs.python.org/3/library/stdtypes.html#dict).
# - [Additional notes on Dictonaries](https://docs.python.org/3/tutorial/datastructures.html#dictionaries)

# %%
a_dict = {
    'server': 'db.jac.qc.ca',
    'database': 'mysql',
    'users': 62
    }
    
print( a_dict['users'] )

a_dict['database']='postgresql'
print( a_dict )

# %% [markdown]
# **Notes:**
#
# - Dictionaries preserve insertion order.

# %% [markdown]
# ## Logic Flow: Match-Case
#
# In Python 3.10, `match-case statements` were introduced.
#
# This works like a switch-case in C#:

# %%
def http_error(status):
    match status:
        case 400:
            return "Bad request"
        case 404:
            return "Not found"
        case 418:
            return "I'm a teapot"

# %% [markdown]
# ## Import Statements
#
# Use `import` to load external code bundled in _packages_.
#
# Most advanced functionality must be imported since very little is loaded by default.

# %%
import random  # import random module

guests = ['Larry', 'Sandy', 'Ian', 'Helen', 'Claudiu']

print( random.choice(guests) )  # pick random item from list

# %% [markdown]
# Import specific functions from a class/library:

# %%
# import mean function from statistics module
from statistics import mean

grades = [78.5, 81, 100, 71.25, 60]
print( mean(grades) )

# %% [markdown]
# ## Functions

# %% [markdown]
# Minimal definition of a function:

# %%
# An empty function
def function():
	pass

# %% [markdown]
# `pass` is used as a set of empty `{}` to satisfy the interpreter.

# %% [markdown]
# Example with data-types for arguments and return value

# %%
# Receives a list of numbers and returns the average
def average(grades: list)-> float:
    
    total = sum(grades)  # sum is a built-in global function
    entries = len(grades)
    return total/entries

grades = [78.5, 81, 100, 71.25, 60]
print( average(grades) )

# %% [markdown]
# ### Optional arguments
#
# Define optional arguments by specifying default values:

# %%
def play_game(game, players=1):
	if players == 1:
		print(f'Playing {game} by myself')
	else:
		print(f'{game} is a lot more fun with more people')		

play_game("tic-tac-toe")

# %% [markdown]
# ### Keyword & Positional Arguments
#
# Function arguments can be passed as:
#
# - Positional arguments _(the standard)_
# - Named arguments
# - Combination of the above

# %%
from datetime import date

def borrow_item(item, borrow_date, return_date):
    print( f"You are borrowing my {item} from {borrow_date} to {return_date}")
    
now = date.today()
next_week = now.replace(day = now.day + 7);

# positional, positional, keyword
borrow_item("camera", now, return_date = next_week)

# %% [markdown]
# **Note**
# - Positional arguments must always come before keyword arguments.

# %% [markdown]
# ### `*args` and `**kwargs`
#
# Functions can take an arbitrary number or arguments.

# %% [markdown]
# Define the argument `*args` to:
#
# - Take unlimited positional arguments;
# - Arguments are available inside the function as a **Tupple**.

# %%
def place_order(item, *args):
    print( f"You are ordering a {item}")
    for order in args:
        print(order)

# Order a single item
place_order("hotdog")

# Order lots
place_order("pizza", "fries", "coffee", "chocolate", "cola")

# %% [markdown]
# Define the argument `**kwargs` to:
#
# - Receive an unlimited number of keyword arguments;
# - These arguments are available inside the function as a **Dictionary**.

# %%
def place_order_extra(item, **kwargs):
    print( f"You are ordering a {item}")
    for key in kwargs:
        print(f"As a {key}: {kwargs[key]}")

# Order a single item
place_order_extra("hotdog")

# Order lots
place_order_extra("pizza", side="fries", drink="coffee", desert="chocolate")

# %% [markdown]
# **Note**
# - The variable names `args` and `kwargs` are simply a convention.
# - It is the `*` and `**` operators that unpack the arguments.

# %% [markdown]
# ## Warm-up Exercises:
#
# Take 15 mins to complete the following:
#
# - [Lists Exercises 4 to 8](https://www.w3schools.com/python/exercise.asp?filename=exercise_lists4).
#
# - [Dictionaty Exercises 1 to 5](https://www.w3schools.com/python/exercise.asp?filename=exercise_dictionaries1)
#
# - [Functions exercises 4 to 6](https://www.w3schools.com/python/exercise.asp?filename=exercise_functions4).

# %% [markdown]
# ## Object Oriented Python

# %% [markdown]
# ### Classes
#
# > Docs on [Python Classes](https://docs.python.org/3/tutorial/classes.html).
#
#
# The most basic class declaration:

# %%
class Vehicle:
	pass      # pass is required

# %% [markdown]
# ### Constructor & Attributes
#
# The method `__init__()` is the class "constructor".
#
# - `self` is the first constructor argument and **is mandatory**.
#     - It refers to the current class instance.

# %%
class Person:
    # constructor
    def __init__(self, name:str, age:int):
        self.name = name
        self.age = age

    # method
    def greeting(self):
        print(f"Hi, I'm {self.name}")

me = Person("Mauricio", 36)
print( me )

# dictionary representation of the object
print( me.__dict__ )

# %% [markdown]
# **Note**
#
# - Printing the object does not results in a "nice print"
# - The method `__repr__` or `__str__` define the string representation of the object.

# %%
class Pet:
    def __init__(self, name:str, age:int, species:str):
        self.name = name
        self.age = age
        self.species = species

    # Defined the string representation of the object
    def __repr__(self):
        return f"Pet ({self.name} the {self.species} is {self.age})"

my_cat = Pet("Jack", 4, "cat")
my_dog = Pet("Loki", 3, "dog")

print( my_cat )
print( my_dog )

# %% [markdown]
# ### Class Inheritance
#
# Inherit from a parent class by including the parent class in its declaration:

# %%
class Student(Person):
    def __init__(self, name, age, student_number):
        super().__init__(name, age)    # use the parent's constructor
        self.student_number= student_number
        
    def study(self):
        print("😭")

jimmy = Student("jimmy", 20, 123456)
jimmy.greeting()   # inherited from parent class
jimmy.study()

# %% [markdown]
# ### Private Class Members
#
# In Python has no private class attributes, **only conventions**.

# %% [markdown]
# The convention is based on prefixes onthe class member name:
#
# - Prefixed with underscore (e.g. `_spam`):
#     - Treat it as private. _(aka. don't touch this)_
#
# - Prefixed with double-underscore (e.g. `__salary`):
#     - Treat it as private and cannot be accessed by name alone. _(aka. can't touch this)_

# %%
class Teacher(Person):
    def __init__(self, name: str, age: int, email: str, salary: int):
         super().__init__(name, age)
         self._email = email
         self.__salary = salary

    def __procrastinate(self):
        print( "YouTube... Yeah!")

vik = Teacher("Vik", 33, "vik@jac.qc.ca", 99999)

print( vik._email )   # supposed to treat it as private!

print( vik.__salary )  # can't touch this
vik.__procrastinate()

# %% [markdown]
# The double underscore convention changes the attribute name with `_className__` to make it difficult to access by "mistake". However, it's still there. This technique is called _name mangling_.

# %%
# Accessing "private" attribute
print( vik._Teacher__salary )
vik._Teacher__procrastinate()

# %% [markdown]
# ## Getting Help Inside Python
#
# 3 easy ways to get "quick help" inside Python:
#
# - See all attributes and methods included in an object:
#     - `dir(<object>)`
#     - Ideal when wondering: _what can this do_?
#
# - Show internal documentation for an object with:
#     - `help(<object>)`
#     - `<object>._doc_`

# %% [markdown]
# ## Future Python Topics
#
# Future Python topics that will be covered in this course:
#
# - Abstract Classes & Interfaces:
#     - Defining abstract classes with [module ABC](https://docs.python.org/3/library/abc.html)
#
# - Using Getter, Setters and Deleter
#     - With the [@property decorator](https://www.freecodecamp.org/news/python-property-decorator/).
#
# - Simplifying classes that capture information (rather an actions):
#     - With [@dataclass decorator](https://docs.python.org/3/library/dataclasses.html).
#
# - Organizing code into [modules](https://docs.python.org/3/tutorial/modules.html).
#
# - Running files in main program or imported modules:
#     - With `if __name__ == "__main__":`
#
# - Automated [tests with pytest](https://code.visualstudio.com/docs/python/testing).

# %% [markdown]
# ## Learning Resources
#
# For detailed tutorials on Python basics:
#
# 1. [Learn Python](https://www.kaggle.com/learn/python) by Kaggle.com.
# 2. [Intro to object-oriented programming with Python](https://learn.microsoft.com/en-us/training/modules/python-object-oriented-programming/) by Microsoft training.

# %% [markdown]
# ## Exercises
#
# Complete the exercises using either VS Code or [OnlinePython](https://www.online-python.com/) as your IDE.

# %% [markdown]
# **Exercise 1**
#
# Create a Bus and a Car class that inherits from the Vehicle class. Implement the requirements bellow.
#
# The Bus class should:
# - Have a `signage` property containing the bus destination.
# - Have a `change_destination` method to update the destination description.
#
# The Car class should:
# - Have a `max_speed` property.
# - Have a `trip_time` method that takes a distance (in kms) and returns the trip time (hrs) assuming the car moves at `max_speed`.
#
# See the expected output when your code is ran.

# %%
class Vehicle:
    def __init__(self, name:str, max_speed:int, capacity:int):
        self.name = name
        self.max_speed = max_speed
        self.capacity = capacity

    def announce_capacity(self, capacity):
        return f"This {self.name} can carry {capacity} passengers"

# Define Classes Bus and Car here.

# ...

# Instantiate your objects here so that the code below works

# ...

stm_bus.announce_capacity()
stm_bus.change_destination("747 Airport")

beetle.announce_capacity()
print( beetle.trip_time(200) )
